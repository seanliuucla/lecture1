# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv('/content/gdrive/MyDrive/ECON441B/spotify_cut.csv')

# %%
# only using the top 200 songs on 2017/01/01
df0101 = df[:200]

# %%
df
# Out:
#       Unnamed: 0  Position              Track Name           Artist  Streams  \
# 0              0         1   ReggaetnLentoBailemos             CNCO    19272
# 1              1         2                Chantaje          Shakira    19270
# 2              2         3      OtraVezfeatJBalvin       ZionLennox    15761
# 3              3         4               VentePaCa      RickyMartin    14954
# 4              4         5                  Safari          JBalvin    14269
# ...          ...       ...                     ...              ...      ...
# 4079        4079        80        EncantadoraRemix           Yandel     2899
# 4080        4080        81             StressedOut  TwentyOnePilots     2839
# 4081        4081        82    ThisIsWhatYouCameFor     CalvinHarris     2810
# 4082        4082        83         HastaelAmanecer         NickyJam     2810
# 4083        4083        84  CorazonDeSedafeatOzuna          Klasico     2805
#
# ...

# %%
df_song = df.loc[df['Track Name']=='Chantaje']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
x_axis = df_song['Date']
y_axis = df_song['Streams']
plt.bar(x_axis, y_axis)
plt.xlabel('Date')
plt.xticks(rotation=90)
plt.ylabel('Streams')
plt.ylim(ymin=10000)

plt.title("Chantaje Streams Plot")
plt.grid()
plt.show()

# %% [markdown]
# Observation: There appears to be a weekly pattern for the streams of Chantaje. 20217/01/01 was a Sunday. It seems that higher streams happened on Saturdays, folled by Sundays.
